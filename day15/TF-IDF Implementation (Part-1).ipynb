# %% [markdown]
# # TF-IDF: Implementation (Part-1)

# %% [markdown]
# The theory of the TF-IDF has already been discussed in the last article. The current article describes the implementation component of it. The first section describes a little about the data type and the variables chosen for the classification model.

# %% [markdown]
# ### Problem Statement
#
# The data contains 200,853 records with 6 columns. For ease of illustration, I am going to take the title of the articles and the categorization column. The data snapshot has been provided below:

# %% [markdown]
# ![1623774370180.png](attachment:1623774370180.png)

# %% [markdown]
# The articles provided in the table are required to be classified into several categories. I have pulled out the top two categories as depicted in the image below:

# %% [markdown]
# ![1623774386678.png](attachment:1623774386678.png)

# %% [markdown]
# ### Text Analysis
#
# As described above, I have taken only two categories here: POLITICS and WELLNESS. The following techniques of analysis will give the difference between the two data-title types.
#
# 1. **WordCloud:**
# Politics

# %% [markdown]
# ![1623780442235.png](attachment:1623780442235.png)

# %% [markdown]
# Wellness
#
# ![1623780480927.png](attachment:1623780480927.png)

# %% [markdown]
# You can observe the clear word compositions of the two texts. Politics is dominated by trump and wellness by word health. Similar observations are from the frequency plots.

# %% [markdown]
# 2. **Frequency Plots:**
#
# Politics
#
# [1623780625045.png](attachment:1623780625045.png)
#
# Wellness
#
# [1623780640496.png](attachment:1623780640496.png)
#
# As per the top 15 words as well, the composition is evident and these two categories are very different and due to this differentiation even a bag of word models can also be used.
#
# We will look at further step in the next article. Till then Stay Tuned!!
