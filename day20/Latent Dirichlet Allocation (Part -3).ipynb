# %% [markdown]
# # Latent Dirichlet Allocation (Part -3)

# %% [markdown]
# The theory and implementation of the model have been provided in the last two articles. This article is primarily about the visualization part of it. Visualization makes the entire exercise and interpretation part easier. I have already explained the word cloud and frequency distributions in the previous series of articles.
#
# 1. **The topic-wise distribution of the word count**: The below-presented graph depicts the word count of rows in headlines. The distribution differs for topic 0, topic 1, and overall.
#
# ![1624210768500.png](attachment:1624210768500.png)

# %% [markdown]
# 2. Word count for each word in a token: The model releases the topic word list with probabilities corresponding to it. For the below graphs I have taken those important words and have calculated the corresponding word count to those words.
#
# 2.1 Topic 0: 'POLITICS'
#
# ![1624211106925.png](attachment:1624211106925.png)
#
# 2.2 Topic 1: 'WELLNESS'
#
# ![1624211131673.png](attachment:1624211131673.png)
#
# For now, this is the visualization part of it. More like t-sne will be described later in this series.
#
# I hope you enjoyed the article. In case of queries please feel free to reach out to me.
#
# Stay Tuned !!
