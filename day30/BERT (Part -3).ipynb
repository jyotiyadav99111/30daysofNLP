# %% [markdown]
# # BERT (Part -3)

# %% [markdown]
# In the last two articles, I have described each element of the BERT model. This article combines all the concepts of the last article to show the complete picture of the BERT model.
#
# ### Illustration
#
# 1. Pre-trained Model
#
# ![1625069137691.png](attachment:1625069137691.png)
#
# This is the pre-trained model with a huge input corpus. The parameters are already tuned through this model.
#
# 2. Transfer learning
#
# ![1625070989921.png](attachment:1625070989921.png)
#
# The model which has been trained in the previous point is to be trained over the new movie review data. The review data which has been added to the model will fine-tune the model.
#
# This is the end of the #30daysofNLP series. I hope you enjoyed the series!
